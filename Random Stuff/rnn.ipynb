# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

DATA_PATH = r"C:\Users\Asus\Desktop\Music-Genre-Classification\data_10.json"


def load_data(data_path):
    """Loads training dataset from json file.

        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(data_path, "r") as fp:
        data = json.load(fp)

    X = np.array(data["mfcc"])
    y = np.array(data["labels"])
    return X, y


def plot_history(history):
    """Plots accuracy/loss for training/validation set as a function of the epochs

        :param history: Training history of model
        :return:
    """

    fig, axs = plt.subplots(2)

    # create accuracy sublpot
    axs[0].plot(history.history["accuracy"], label="train accuracy")
    axs[0].plot(history.history["val_accuracy"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy evaluation")

    # create error sublpot
    axs[1].plot(history.history["loss"], label="train error")
    axs[1].plot(history.history["val_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error evaluation")
    
    plt.subplots_adjust(hspace=0.8)

    plt.show()


def prepare_datasets(test_size, validation_size):
    """Loads data and splits it into train, validation and test sets.

    :param test_size (float): Value in [0, 1] indicating percentage of data set to allocate to test split
    :param validation_size (float): Value in [0, 1] indicating percentage of train set to allocate to validation split

    :return X_train (ndarray): Input training set
    :return X_validation (ndarray): Input validation set
    :return X_test (ndarray): Input test set
    :return y_train (ndarray): Target training set
    :return y_validation (ndarray): Target validation set
    :return y_test (ndarray): Target test set
    """

    # load data
    X, y = load_data(DATA_PATH)

    # create train, validation and test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)

    return X_train, X_validation, X_test, y_train, y_validation, y_test


def build_model(input_shape):
    """Generates RNN-LSTM model

    :param input_shape (tuple): Shape of input set
    :return model: RNN-LSTM model
    """

    # build network topology
    model = keras.Sequential()

    # 2 LSTM layers
    model.add(keras.layers.LSTM(64, input_shape=input_shape, return_sequences=True))
    model.add(keras.layers.LSTM(64))

    # dense layer
    model.add(keras.layers.Dense(64, activation='relu'))
    model.add(keras.layers.Dropout(0.3))

    # output layer
    model.add(keras.layers.Dense(10, activation='softmax'))

    return model


if __name__ == "__main__":

    # get train, validation, test splits
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.25, 0.2)

    # create network
    input_shape = (X_train.shape[1], X_train.shape[2]) # 130, 13
    model = build_model(input_shape)

    # compile model
    optimiser = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=optimiser,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])

    model.summary()

    # train model
    history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=32, epochs=40)

    # plot accuracy/error for training and validation
    plot_history(history)

    # evaluate model on test set
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
    print('\nTest accuracy:', test_acc)
    
    genre_names = [
    "Adhunik", "Folk", "Hiphop", "Indie", 
    "Islamic", "Metal", "Pop", "Rock"
    ]
    
    
    # Generate predictions for the test set
    y_pred = model.predict(X_test)
    y_pred_classes = np.argmax(y_pred, axis=1)
    
    # Generate classification report
    print(classification_report(y_test, y_pred_classes))

    # Generate confusion matrix
    cm = confusion_matrix(y_test, y_pred_classes)
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, cmap="Blues", fmt="d", xticklabels=genre_names, yticklabels=genre_names)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    plt.show()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 130, 64)           19968
#
#  lstm_1 (LSTM)               (None, 64)                33024
#
#  dense (Dense)               (None, 64)                4160
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 57,802
# Trainable params: 57,802
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 150/150 [==============================] - 32s 164ms/step - loss: 2.2247 - accuracy: 0.1721 - val_loss: 2.0896 - val_accuracy: 0.2608
# Epoch 2/40
# 150/150 [==============================] - 24s 158ms/step - loss: 1.9644 - accuracy: 0.2763 - val_loss: 1.8350 - val_accuracy: 0.3225
# Epoch 3/40
# 150/150 [==============================] - 21s 138ms/step - loss: 1.7462 - accuracy: 0.3590 - val_loss: 1.6305 - val_accuracy: 0.4042
# Epoch 4/40
# 150/150 [==============================] - 24s 162ms/step - loss: 1.5694 - accuracy: 0.4238 - val_loss: 1.4923 - val_accuracy: 0.4475
# Epoch 5/40
# 150/150 [==============================] - 25s 165ms/step - loss: 1.4830 - accuracy: 0.4502 - val_loss: 1.4349 - val_accuracy: 0.4683
# Epoch 6/40
# 150/150 [==============================] - 21s 141ms/step - loss: 1.4170 - accuracy: 0.4665 - val_loss: 1.3863 - val_accuracy: 0.4808
# Epoch 7/40
# 150/150 [==============================] - 22s 149ms/step - loss: 1.3554 - accuracy: 0.4892 - val_loss: 1.3478 - val_accuracy: 0.4975
# Epoch 8/40
# 150/150 [==============================] - 25s 167ms/step - loss: 1.3203 - accuracy: 0.5058 - val_loss: 1.3282 - val_accuracy: 0.4950
# Epoch 9/40
# 150/150 [==============================] - 25s 164ms/step - loss: 1.2840 - accuracy: 0.5144 - val_loss: 1.3224 - val_accuracy: 0.5050
# Epoch 10/40
# 150/150 [==============================] - 26s 176ms/step - loss: 1.2442 - accuracy: 0.5337 - val_loss: 1.3096 - val_accuracy: 0.5100
# Epoch 11/40
# 150/150 [==============================] - 27s 180ms/step - loss: 1.2292 - accuracy: 0.5333 - val_loss: 1.2919 - val_accuracy: 0.5108
# Epoch 12/40
# 150/150 [==============================] - 22s 146ms/step - loss: 1.2048 - accuracy: 0.5440 - val_loss: 1.2754 - val_accuracy: 0.5108
# Epoch 13/40
# 150/150 [==============================] - 22s 146ms/step - loss: 1.1845 - accuracy: 0.5602 - val_loss: 1.2684 - val_accuracy: 0.5142
# Epoch 14/40
# 150/150 [==============================] - 23s 156ms/step - loss: 1.1674 - accuracy: 0.5554 - val_loss: 1.2786 - val_accuracy: 0.5075
# Epoch 15/40
# 150/150 [==============================] - 21s 140ms/step - loss: 1.1450 - accuracy: 0.5602 - val_loss: 1.2583 - val_accuracy: 0.5150
# Epoch 16/40
# 150/150 [==============================] - 21s 140ms/step - loss: 1.1283 - accuracy: 0.5765 - val_loss: 1.2604 - val_accuracy: 0.5058
# Epoch 17/40
# 150/150 [==============================] - 22s 149ms/step - loss: 1.1076 - accuracy: 0.5781 - val_loss: 1.2699 - val_accuracy: 0.5167
# Epoch 18/40
# 150/150 [==============================] - 21s 139ms/step - loss: 1.0874 - accuracy: 0.5892 - val_loss: 1.2592 - val_accuracy: 0.5167
# Epoch 19/40
# 150/150 [==============================] - 20s 131ms/step - loss: 1.0859 - accuracy: 0.5869 - val_loss: 1.3000 - val_accuracy: 0.5167
# Epoch 20/40
# 150/150 [==============================] - 20s 134ms/step - loss: 1.0787 - accuracy: 0.5900 - val_loss: 1.2538 - val_accuracy: 0.5058
# Epoch 21/40
# 150/150 [==============================] - 20s 134ms/step - loss: 1.0803 - accuracy: 0.5879 - val_loss: 1.2375 - val_accuracy: 0.5242
# Epoch 22/40
# 150/150 [==============================] - 20s 132ms/step - loss: 1.0572 - accuracy: 0.5998 - val_loss: 1.2403 - val_accuracy: 0.5208
# Epoch 23/40
# 150/150 [==============================] - 20s 131ms/step - loss: 1.0259 - accuracy: 0.6112 - val_loss: 1.2461 - val_accuracy: 0.5200
# Epoch 24/40
# 150/150 [==============================] - 20s 131ms/step - loss: 1.0031 - accuracy: 0.6221 - val_loss: 1.2448 - val_accuracy: 0.5192
# Epoch 25/40
# 150/150 [==============================] - 20s 131ms/step - loss: 1.0088 - accuracy: 0.6169 - val_loss: 1.2484 - val_accuracy: 0.5225
# Epoch 26/40
# 150/150 [==============================] - 20s 132ms/step - loss: 1.0107 - accuracy: 0.6179 - val_loss: 1.2391 - val_accuracy: 0.5292
# Epoch 27/40
# 150/150 [==============================] - 20s 132ms/step - loss: 0.9810 - accuracy: 0.6310 - val_loss: 1.2745 - val_accuracy: 0.5033
# Epoch 28/40
# 150/150 [==============================] - 20s 132ms/step - loss: 0.9855 - accuracy: 0.6344 - val_loss: 1.2544 - val_accuracy: 0.5250
# Epoch 29/40
# 150/150 [==============================] - 20s 132ms/step - loss: 0.9924 - accuracy: 0.6267 - val_loss: 1.3383 - val_accuracy: 0.5158
# Epoch 30/40
# 150/150 [==============================] - 20s 132ms/step - loss: 0.9742 - accuracy: 0.6321 - val_loss: 1.2342 - val_accuracy: 0.5283
# Epoch 31/40
# 150/150 [==============================] - 20s 132ms/step - loss: 0.9649 - accuracy: 0.6344 - val_loss: 1.2257 - val_accuracy: 0.5325
# Epoch 32/40
# 150/150 [==============================] - 20s 131ms/step - loss: 0.9376 - accuracy: 0.6452 - val_loss: 1.2396 - val_accuracy: 0.5358
# Epoch 33/40
# 150/150 [==============================] - 20s 135ms/step - loss: 0.9284 - accuracy: 0.6554 - val_loss: 1.2452 - val_accuracy: 0.5242
# Epoch 34/40
# 150/150 [==============================] - 20s 132ms/step - loss: 0.9201 - accuracy: 0.6535 - val_loss: 1.2332 - val_accuracy: 0.5250
# Epoch 35/40
# 150/150 [==============================] - 20s 133ms/step - loss: 0.9057 - accuracy: 0.6585 - val_loss: 1.2443 - val_accuracy: 0.5400
# Epoch 36/40
# 150/150 [==============================] - 20s 136ms/step - loss: 0.9029 - accuracy: 0.6654 - val_loss: 1.2448 - val_accuracy: 0.5408
# Epoch 37/40
# 150/150 [==============================] - 27s 178ms/step - loss: 0.9020 - accuracy: 0.6583 - val_loss: 1.2380 - val_accuracy: 0.5367
# Epoch 38/40
# 150/150 [==============================] - 24s 163ms/step - loss: 0.8872 - accuracy: 0.6612 - val_loss: 1.2471 - val_accuracy: 0.5425
# Epoch 39/40
# 150/150 [==============================] - 24s 159ms/step - loss: 0.8750 - accuracy: 0.6717 - val_loss: 1.2532 - val_accuracy: 0.5350
# Epoch 40/40
# 150/150 [==============================] - 23s 153ms/step - loss: 0.8530 - accuracy: 0.6831 - val_loss: 1.2465 - val_accuracy: 0.5392
# 63/63 - 4s - loss: 1.1880 - accuracy: 0.5710 - 4s/epoch - 64ms/step
#
# Test accuracy: 0.5709999799728394
# 63/63 [==============================] - 6s 75ms/step
#               precision    recall  f1-score   support
#
#            0       0.47      0.44      0.46       230
#            1       0.34      0.38      0.36       241
#            2       0.81      0.82      0.81       257
#            3       0.47      0.46      0.46       279
#            4       0.82      0.87      0.85       245
#            5       0.82      0.71      0.76       249
#            6       0.41      0.34      0.37       270
#            7       0.45      0.56      0.50       229
#
#     accuracy                           0.57      2000
#    macro avg       0.57      0.57      0.57      2000
# weighted avg       0.57      0.57      0.57      2000

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 hi
#
# NameError: name 'hi' is not defined
